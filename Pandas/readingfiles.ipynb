# %%
import pandas as pd 
import json

from io import StringIO

# %%
data = '{"country name":"India" , "population" :"150 crores"}'
json.loads(data)
# Out:
# {'country name': 'India', 'population': '150 crores'}

# %%
type(data)
# Out:
# str

# %%
df = pd.read_json(StringIO(data), typ="series")
# Out:
# country name         India
# population      150 crores
# dtype: str

# %%
df = pd.read_json(StringIO(data),orient='index')
df
# Out:
#                        0
# country name       India
# population    150 crores

# %%
df = pd.DataFrame([[1,3],[3,4]],
                  index= ['row 1','row 2'],
                  columns=['column 1', 'column 2'])
df
# Out:
#        column 1  column 2
# row 1         1         3
# row 2         3         4

# %%
df.to_json()
# Out:
# '{"column 1":{"row 1":1,"row 2":3},"column 2":{"row 1":3,"row 2":4}}'

# %%
df.to_json(orient='index')
# Out:
# '{"row 1":{"column 1":1,"column 2":3},"row 2":{"column 1":3,"column 2":4}}'

# %%
df.to_json(orient='columns')

# priority on column
# Out:
# '{"column 1":{"row 1":1,"row 2":3},"column 2":{"row 1":3,"row 2":4}}'

# %%
df.to_json(orient='split')
# Out:
# '{"columns":["column 1","column 2"],"index":["row 1","row 2"],"data":[[1,3],[3,4]]}'

# %%
df.to_json(orient='records')
# Out:
# '[{"column 1":1,"column 2":3},{"column 1":3,"column 2":4}]'
