# %% [markdown]
# # <font color="maroon"><h4 align="center">Pandas Concat and Merge: Exercise</h4></font>

# %%
import pandas as pd

# %% [markdown]
# ### <font color="purple">**Question1**</font>
# - Read the 3 csv files provided into seperate dataframes (movies.csv to df_movies, financials.csv to df_financials, languages.csv to df_languages).
# - show the top 3 rows for each dataframe.

# %%
#for movies.csv

df_movies = pd.read_csv('movies.csv')

#for financials.csv

df_financials = pd.read_csv('financials.csv')


#for languages.csv

df_languages = pd.read_csv('languages.csv')

# %%
#show top3 rows in df_movies

df_movies.head(3)
# Out:
#    movie_id                                        title   industry  \
# 0       101                             K.G.F: Chapter 2  Bollywood
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       103                        Thor: The Dark World   Hollywood
#
#    release_year  imdb_rating          studio  language_id
# 0          2022          8.4   Hombale Films            3
# 1          2022          7.0  Marvel Studios            5
# 2          2013          6.8  Marvel Studios            5

# %%
#show top3 rows in df_financials

df_financials.head(3)
# Out:
#    movie_id  budget  revenue      unit currency
# 0       101     1.0     12.5  Billions      INR
# 1       102   200.0    954.8  Millions      USD
# 2       103   165.0    644.8  Millions      USD

# %%
#show top3 rows in df_languages

df_languages.head(3)
# Out:
#    language_id lang_name
# 0            1     Hindi
# 1            2    Telugu
# 2            3   Kannada

# %% [markdown]
# ### <font color="purple">**Question2**</font>
# - Read the csv file 'new_movies.csv' and store it into dataframe 'df_new_movies'
# - Now, concat the dataframes [df_movies, df_new_movies] and store the results again to df_movies. Make sure to ignore the index while concatenating

# %%
#read the csv file: 'new_movies.csv'

df_new_movies = pd.read_csv('new_movies.csv')

#show the dataframe

print(df_new_movies)
# Out:
#    movie_id                           title   industry  release_year  \
# 0       201                         Pathaan  Bollywood          2023
# 1       210                          Vikram  Bollywood          2022
# 2       240  Black Panther: Wakanda Forever  Hollywood           200
#
#    imdb_rating                          studio  language_id
# 0          6.6                  Yash Raj Films            1
# 1          8.3  Raaj Kamal Films International            4
# 2          6.9                  Marvel Studios            5

# %%
#concat the two dataframes ['df_movies', df_new_movies]

df_movies = pd.concat([df_movies,df_new_movies],ignore_index=True)

#show the last 5 rows

df_movies.tail(5)
# Out:
#     movie_id                           title   industry  release_year  \
# 37       139                          Race 3  Bollywood          2018
# 38       140                       Shershaah  Bollywood          2021
# 39       201                         Pathaan  Bollywood          2023
# 40       210                          Vikram  Bollywood          2022
# 41       240  Black Panther: Wakanda Forever  Hollywood           200
#
#     imdb_rating                          studio  language_id
# 37          1.9               Salman Khan Films            1
# 38          8.4              Dharma Productions            1
# 39          6.6                  Yash Raj Films            1
# 40          8.3  Raaj Kamal Films International            4
# 41          6.9                  Marvel Studios            5

# %% [markdown]
# ### <font color="purple">**Question3**</font>
#
# - Merge the dataframe df_movies with the df_languages on 'language_id'.
# - Make sure you perform a **inner** join here.
# - Store the result again to df_movies

# %%
#perform the join operation

df_movies = pd.merge(df_movies,df_languages ,on='language_id' , how="inner")

#show the top 5 rows


df_movies.head(5)
# Out:
#    movie_id                                        title   industry  \
# 0       101                             K.G.F: Chapter 2  Bollywood
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       103                        Thor: The Dark World   Hollywood
# 3       104                              Thor: Ragnarok   Hollywood
# 4       105                      Thor: Love and Thunder   Hollywood
#
#    release_year  imdb_rating          studio  language_id lang_name
# 0          2022          8.4   Hombale Films            3   Kannada
# 1          2022          7.0  Marvel Studios            5   English
# 2          2013          6.8  Marvel Studios            5   English
# 3          2017          7.9  Marvel Studios            5   English
# 4          2022          6.8  Marvel Studios            5   English

# %% [markdown]
# ### <font color="purple">**Question4**</font>
#
# - Merge the dataframe df_movies with the df_financials on 'movie_id'.
# - Make sure you perform a **left** join here.
# - Store the result again to df_movies

# %%
#perform the join operation

df_movies = pd.merge(df_movies,df_financials ,on='movie_id' , how="left")

#show the last 5 rows

df_movies.tail(5)
# Out:
#     movie_id                           title   industry  release_year  \
# 37       139                          Race 3  Bollywood          2018
# 38       140                       Shershaah  Bollywood          2021
# 39       201                         Pathaan  Bollywood          2023
# 40       210                          Vikram  Bollywood          2022
# 41       240  Black Panther: Wakanda Forever  Hollywood           200
#
#     imdb_rating                          studio  language_id lang_name  \
# 37          1.9               Salman Khan Films            1     Hindi
# 38          8.4              Dharma Productions            1     Hindi
# 39          6.6                  Yash Raj Films            1     Hindi
# 40          8.3  Raaj Kamal Films International            4     Tamil
# 41          6.9                  Marvel Studios            5   English
#
#     budget  revenue      unit currency
# 37     1.8      3.1  Billions      INR
# 38   500.0    950.0  Millions      INR
# 39     NaN      NaN       NaN      NaN
# 40     NaN      NaN       NaN      NaN
# 41     NaN      NaN       NaN      NaN

# %% [markdown]
# ### <font color="purple">**Question5**</font>
#
# - Save the 'df_movies' dataframe with name 'final_complete_data.csv'.
# - Only take the columns 'movie_id', 'title', 'lang_name', 'budget', 'revenue', 'currency'
# - set the index to False while saving the dataframe

# %%
#save the dataframe to 'final_complete_data.csv'

df_movies = df_movies[['movie_id', 'title', 'lang_name', 'budget', 'revenue', 'currency']]

df_movies.to_csv('final_complete_data.csv',index=False)

pd.read_csv('final_complete_data.csv')
# Out:
#     movie_id                                        title lang_name    budget  \
# 0        101                             K.G.F: Chapter 2   Kannada      1.00
# 1        102  Doctor Strange in the Multiverse of Madness   English    200.00
# 2        103                        Thor: The Dark World    English    165.00
# 3        104                              Thor: Ragnarok    English    180.00
# 4        105                      Thor: Love and Thunder    English    250.00
# 5        106                                       Sholay     Hindi       NaN
# 6        107                  Dilwale Dulhania Le Jayenge     Hindi    400.00
# 7        108                                     3 Idiots     Hindi    550.00
# 8        109                     Kabhi Khushi Kabhie Gham     Hindi    390.00
# 9        110                             Bajirao Mastani      Hindi      1.40
# 10       111                     The Shawshank Redemption   English     25.00
# 11       112                                    Inception   English       NaN
# 12       113                                 Interstellar   English    165.00
# 13       115                     The Pursuit of Happyness   English     55.00
# 14       116                                    Gladiator   English    103.00
# 15       117                                      Titanic   English    200.00
# 16       118                        It's a Wonderful Life   English      3.18
# 17       119                                       Avatar   English    237.00
# 18       120                                The Godfather   English      7.20
# 19       121                              The Dark Knight   English    185.00
# 20       122                             Schindler's List   English     22.00
# 21       123                                Jurassic Park   English     63.00
# 22       124                                     Parasite   English     15.50
# 23       125                            Avengers: Endgame   English    400.00
# 24       126                       Avengers: Infinity War   English    400.00
# 25       127                              Pather Panchali   Bengali  70000.00
# 26       128                             Taare Zameen Par     Hindi    120.00
# 27       129                          Munna Bhai M.B.B.S.     Hindi    100.00
# 28       130                                           PK     Hindi    850.00
# 29       131                                        Sanju     Hindi      1.00
# 30       132                    Pushpa: The Rise - Part 1    Telugu      2.00
# 31       133                                          RRR    Telugu      5.50
# 32       134                     Baahubali: The Beginning    Telugu      1.80
# 33       135                            The Kashmir Files     Hindi    250.00
# 34       136                            Bajrangi Bhaijaan     Hindi    900.00
# 35       137           Captain America: The First Avenger   English    216.70
# 36       138          Captain America: The Winter Soldier   English    177.00
# 37       139                                       Race 3     Hindi      1.80
# 38       140                                    Shershaah     Hindi    500.00
# 39       201                                      Pathaan     Hindi       NaN
# 40       210                                       Vikram     Tamil       NaN
# 41       240               Black Panther: Wakanda Forever   English       NaN
#
#      revenue currency
# 0       12.5      INR
# 1      954.8      USD
# 2      644.8      USD
# 3      854.0      USD
# 4      670.0      USD
# 5        NaN      NaN
# 6     2000.0      INR
# 7     4000.0      INR
# 8     1360.0      INR
# 9        3.5      INR
# 10      73.3      USD
# 11       NaN      NaN
# 12     701.8      USD
# 13     307.1      USD
# 14     460.5      USD
# 15    2202.0      USD
# 16       3.3      USD
# 17    2847.0      USD
# 18     291.0      USD
# 19    1006.0      USD
# 20     322.2      USD
# 21    1046.0      USD
# 22     263.1      USD
# 23    2798.0      USD
# 24    2048.0      USD
# 25  100000.0      INR
# 26    1350.0      INR
# 27     410.0      INR
# 28    8540.0      INR
# 29       5.9      INR
# 30       3.6      INR
# 31      12.0      INR
# 32       6.5      INR
# 33    3409.0      INR
# 34   11690.0      INR
# 35     370.6      USD
# 36     714.4      USD
# 37       3.1      INR
# 38     950.0      INR
# 39       NaN      NaN
# 40       NaN      NaN
# 41       NaN      NaN
